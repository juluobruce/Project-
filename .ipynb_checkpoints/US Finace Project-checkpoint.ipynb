# %% [markdown]
# # Cleaning

# %%
#dependencies

import pandas as pd
from sqlalchemy import create_engine
import pandas as pd
import csv 
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
# Store CSV into DataFrame
districts = "Resources/districts.csv"
naep = "Resources/naep.csv"
states = "Resources/states.csv"


naep_pd = pd.read_csv(naep)
districts_pd = pd.read_csv(districts)
states_pd = pd.read_csv(states)

# %%
#Naep_pd focus:
#naep_states.csv: Aggregated results from the National Assessment of Educational Progress (NAEP) for states.
#focusing on 4th & 8th grades 
# year ranges from 1990-2017, but missing 91, 93, 95, 97,99, 2001, 05, 06, 08, 10, 14, 16: total 15 years  

#print(naep_pd)
#naep_pd['YEAR'].unique()
#naep_pd['AVG_SCORE'].value_counts()
    # there is null values being shown as: "-- & ‡" on AVG_SCORE cloumn
    #To clean and change it to 0:
#mask1 = (naep_pd['AVG_SCORE'] == '—')
#naep_pd['AVG_SCORE'][mask1] = 0
#mask2 = (naep_pd['AVG_SCORE'] == '‡')
#naep_pd['AVG_SCORE'][mask2] = 0

#naep_pd['TEST_SUBJECT'].value_counts()
#naep_pd['TEST_YEAR'].value_counts() 
#naep_pd['TEST_YEAR'].unique()



#naep_pd.columns
naep_pd.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    YEAR       STATE         AVG_SCORE TEST_SUBJECT  TEST_YEAR
# 0  2017     Alabama  232.170687741509  Mathematics          4
# 1  2017      Alaska  230.456277558902  Mathematics          4
# 2  2017     Arizona  234.435788152091  Mathematics          4
# 3  2017    Arkansas  233.848143678937  Mathematics          4
# 4  2017  California  232.262940994562  Mathematics          4

# %%
#Clean up for SQL

#rename for lowercase columns 
naep_pd = naep_pd.rename(columns={'YEAR': 'year',
                                 'STATE': 'state',
                                 'AVG_SCORE': 'avg_score',
                                 'TEST_SUBJECT': 'subject',
                                 'TEST_YEAR': 'grade'})

naep_pd.head()
# Out:
#    year       state         avg_score      subject  grade
# 0  2017     Alabama  232.170687741509  Mathematics      4
# 1  2017      Alaska  230.456277558902  Mathematics      4
# 2  2017     Arizona  234.435788152091  Mathematics      4
# 3  2017    Arkansas  233.848143678937  Mathematics      4
# 4  2017  California  232.262940994562  Mathematics      4

# %%
#downloading naep as a csv seperately, so can be used later 
naep_pd.to_csv('naep.csv', index =False)

# %%
districts_pd.head()
#Notes 
    # Revenue comes from income taxes per state, local taxes, fed funds, local misch
    # the data frame splits that: Total: fed, state, local
    # TCURINST: Total current spending for instruction
    # TCURSSVC: Total current spending for support services
    # TCURONON: Other current spending
    # TCAPOUT: Total capital outlay expenditure

# Ensuring values has no "unknown values"

#districts_pd['TOTALREV'].value_counts()
#districts_pd['TFEDREV'].value_counts()
#districts_pd['TLOCREV'].value_counts()
#districts_pd['TOTALEXP'].value_counts()
#districts_pd['TCURINST'].value_counts()
#districts_pd['TCURSSVC'].value_counts()
#districts_pd['TCURONON'].value_counts()
#districts_pd['TCAPOUT'].value_counts()


districts_pd.head(500)
# Out:
#         STATE   ENROLL                                NAME  YRDATA  TOTALREV  \
# 0     Alabama   9609.0      AUTAUGA COUNTY SCHOOL DISTRICT    2016     80867
# 20      1334    8364     3874     15018      7378      4821    1075.0     1572
# 21      2182   12797     3446     17663     10178      5356    1714.0       98
# 22      2707   17402     5096     25478     13510      8079    2382.0      691
# 23      2611   12825     4918     20509     10653      7209    1483.0      930
# 24       993    4367     1792      7238      3824      2705     642.0        0
# 25      6348   38269    17271     65966     31061     22834    4742.0     6640
# 26      3250   15582    12364     30748     15639     10596    2764.0     1698
# 27      2114    7041     4624     13310      7088      4453    1316.0      406
# 28      1307    8686     5107     16985      7551      5172    1345.0     2639
# 29      1589   15851    11991     28870     16117      9453    2559.0      227
# ..       ...     ...      ...       ...       ...       ...       ...      ...
# 470     1723    9142     8002     18158      3030     13765     890.0      467
# 471     2460   19382     3213     25361     11390      8456    1149.0     3593
# 472      541    4516      872      5999      3002      2257     399.0      192
# 473     1359   20213     2954     28601     11594      5907    1157.0     9312
# 474     9110   47753     8102     64864     32014     22019    4493.0     4946
# 475      843    8678      776     13618      4503      2747     496.0     5623
# 476     3458   26565     6085     34789     18949     11182    2435.0      765
# 477     1651   21775     3773     30914     15201      8324    1976.0     4264
# 478      733    6390      952      8181      4648      2516     321.0      650
# 479     1446   13336     1952     15989      8905      5242    1024.0      254
# 480     3241   25899     3161     31208     16484     10356    1943.0      863
# 481     1033    7111      757     10922      4609      3122     597.0     2437
# 482      989    7221      642      7228      3675      2805     454.0      165
# 483      665    3322      585      4120      1990      1747     294.0       75
# 484     6415   47687     6381     57144     29987     19654    4034.0      968
# 485     1396    6038      401      7784      4040      3062     523.0       42
# 486    11021   48883     5737     59713     31193     22932    3403.0     1436
# 487     2595   32699     6471     41012     21151     12059    2037.0     4523
# 488     1187    5406     1326      8523      3301      3918     413.0      644
# 489     3072   21034     2594     25850     14549      8799    1622.0      686
# 490     1483    8817      735     10678      6645      3073     358.0      388
# 491     2130   11984     1490     15256      7627      5891     716.0      712
# 492     1874   10281     1536     13026      7057      4461     848.0      573
# 493     1778    8527     1082     10456      5836      3596     638.0      128
# 494     2553   17473     2211     22148     11945      7262    1825.0      722
# 495     3147    6509     3179     24303      3136      7321    2630.0    11216
# 496     8963   81020    14887    112982     53455     34249    5949.0    13277
# 497     2208   29454     3346     40677     16888     10237    1170.0    11257
# 498      421    3467      715      4320      2339      1621     246.0       36
# 499     1401    9097     1253     10836      5885      3717     668.0      216
#
# [500 rows x 13 columns]

# %%
#checking & rename
#Checking the sum of the revenue fed, state & local & exp     
    
#districts_pd["TOTALREV"].sum()
    # 11605107285
    
#districts_pd["TSTREV"].sum()
    # 5385272201

#districts_pd["TLOCREV"].sum()
    # 5240915749
    
#districts_pd["TOTALEXP"].sum()
    #11737958705

districts_pd.columns
    
#rename 
districts_pd = districts_pd.rename(columns= {'STATE': 'state',
                                             'ENROLL': 'enroll',
                                             'NAME': 'district',
                                             'YRDATA': 'year',
                                             'TOTALREV': 'total_rev',
                                             'TFEDREV': 'fed_rev',
                                             'TSTREV': 'state_rev',
                                             'TLOCREV': 'local_rev',
                                             'TOTALEXP': 'total_exp',
                                             'TCURINST': 'spending_instruction_cur',
                                             'TCURONON': 'sepnding_supprtsrvcs_curr',
                                             'TCURONON': 'other_curr_spending',
                                             'TCAPOUT': 'capital_outlay_exp'})
districts_pd.head()
# Out:
#      state   enroll                        district  year  total_rev  fed_rev  \
# 0  Alabama   9609.0  AUTAUGA COUNTY SCHOOL DISTRICT  2016      80867     7447
# 1  Alabama  30931.0  BALDWIN COUNTY SCHOOL DISTRICT  2016     338236    23710
# 2  Alabama    912.0  BARBOUR COUNTY SCHOOL DISTRICT  2016      10116     2342
# 3  Alabama   2842.0    EUFAULA CITY SCHOOL DISTRICT  2016      26182     3558
# 4  Alabama   3322.0     BIBB COUNTY SCHOOL DISTRICT  2016      32486     3664
#
#    state_rev  local_rev  total_exp  spending_instruction_cur  TCURSSVC  \
# 0      53842      19578      76672                     43843     23941
# 1     145180     169346     299880                    164977     97231
# 2       5434       2340      10070                      4907      3896
# 3      15900       6724      29843                     15302      7901
# 4      21846       6976      31662                     16407     11087
#
#    other_curr_spending  capital_outlay_exp
# 0               6401.0                1506
# 1              19439.0                9749
# 2                975.0                 110
# 3               2274.0                4133
# 4               3122.0                 486

# %%
#download as a csv file
districts_pd.to_csv('districts.csv', index=False)

# %%
states_pd.head()
    # State vs district csv files have different data --
    # district covers more because of because of different districts within a state, where state csv covers more macro

#cleaning 

#states_pd['STATE'].value_counts()
    # each state shows 25 times

#states_pd['YEAR'].value_counts()
    # each year shows up 51 times, 19992-2016

#states_pd['TOTAL_REVENUE'].value_counts()
#states_pd['FEDERAL_REVENUE'].value_counts()
#states_pd['STATE_REVENUE'].value_counts()
    # There's 0 25's
#states_pd['LOCAL_REVENUE'].value_counts()
#states_pd['TOTAL_EXPENDITURE'].value_counts()
#states_pd['INSTRUCTION_EXPENDITURE'].value_counts()
#states_pd['SUPPORT_SERVICES_EXPENDITURE'].value_counts()
#states_pd['OTHER_EXPENDITURE'].value_counts()
#states_pd['CAPITAL_OUTLAY_EXPENDITURE'].value_counts()

#Checking the total rev & expenses
    # -- will get us an understanding which values or columns to keep 
    
#states_pd["TOTAL_REVENUE"].sum()
    #11605107285

#states_pd["FEDERAL_REVENUE"].sum()
    #978919327
    
#states_pd["LOCAL_REVENUE"].sum()
    #5240915749

#states_pd["TOTAL_EXPENDITURE"].sum()
    #11737958705
# Out:
#         STATE  YEAR  ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  STATE_REVENUE  \
# 0     Alabama  1992     NaN        2678885           304177        1659028
# 1      Alaska  1992     NaN        1049591           106780         720711
# 2     Arizona  1992     NaN        3258079           297888        1369815
# 3    Arkansas  1992     NaN        1711959           178571         958785
# 4  California  1992     NaN       26260025          2072470       16546514
#
#    LOCAL_REVENUE  TOTAL_EXPENDITURE  INSTRUCTION_EXPENDITURE  \
# 0         715680            2653798                  1481703
# 1         222100             972488                   498362
# 2        1590376            3401580                  1435908
# 3         574603            1743022                   964323
# 4        7641041           27138832                 14358922
#
#    SUPPORT_SERVICES_EXPENDITURE  OTHER_EXPENDITURE  CAPITAL_OUTLAY_EXPENDITURE
# 0                        735036                NaN                      174053
# 1                        350902                NaN                       37451
# 2                       1007732                NaN                      609114
# 3                        483488                NaN                      145212
# 4                       8520926                NaN                     2044688

# %%
# merging naep and districts 
education_df = pd.merge(naep_pd, districts_pd, on = ["YEAR", "STATE"])

education_df.head()

#education_df['ENROLL'].value_counts()
    # O: no recrods of the students enrolled in that district -- 38369

#education_df['YEAR'].value_counts()
    # 94' - 2015
    
#education_df['STATE'].value_counts()
    #dc is there
    
#education_df['TEST_SUBJECT'].value_counts()
    # consistent: Math & reading 

#education_df['TEST_YEAR'].value_counts()
    #consistent: 4th & 8th grade
# Out:
#    YEAR    STATE         AVG_SCORE TEST_SUBJECT  TEST_YEAR   ENROLL  \
# 0  2015  Alabama  230.977422662321  Mathematics          4   9664.0
# 1  2015  Alabama  230.977422662321  Mathematics          4  30596.0
# 2  2015  Alabama  230.977422662321  Mathematics          4    925.0
# 3  2015  Alabama  230.977422662321  Mathematics          4   2829.0
# 4  2015  Alabama  230.977422662321  Mathematics          4   3357.0
#
#                              NAME  TOTALREV  TFEDREV  TSTREV  TLOCREV  \
# 0  AUTAUGA COUNTY SCHOOL DISTRICT     79665     7574   53244    18847
# 1  BALDWIN COUNTY SCHOOL DISTRICT    330317    23602  143282   163433
# 2  BARBOUR COUNTY SCHOOL DISTRICT     10519     2518    5632     2369
# 3    EUFAULA CITY SCHOOL DISTRICT     26076     3374   16048     6654
# 4     BIBB COUNTY SCHOOL DISTRICT     31825     3586   21687     6552
#
#    TOTALEXP  TCURINST  TCURSSVC  TCURONON  TCAPOUT
# 0     76069     44085     23217    6580.0      691
# 1    297083    155668     99682   19535.0    13256
# 2     10314      5249      3835    1018.0        0
# 3     25602     14887      7494    2184.0      990
# 4     31293     16019     10822    2950.0      858

# %%
# merge education and states 
education_finances_df = pd.merge(education_df, states_pd, on = ["STATE", "YEAR", "ENROLL"])

education_finances_df.head()

#education_finances_df.columns

# some columns repeat each other with different values
    #how do we determine which stays and which drops/gets hidden
    
    # -- checking both state & disrticts -- they have consistent total revenue & expenditures
     # but the only issue that the the state & local revenue is different for both csv files. 
        # the state covers state more & district has different districts. 
        # We can keep the state data on state & local revenue and expenses as well
# Out:
#    YEAR                 STATE         AVG_SCORE TEST_SUBJECT  TEST_YEAR  \
# 0  2015  District of Columbia  231.307525116183  Mathematics          4
# 1  2015  District of Columbia  263.059776256545  Mathematics          8
# 2  2015  District of Columbia  212.305347670353      Reading          4
# 3  2015  District of Columbia  247.653444946724      Reading          8
# 4  2015                Hawaii  237.895806837329  Mathematics          4
#
#      ENROLL                                 NAME  TOTALREV  TFEDREV   TSTREV  \
# 0   46155.0  DISTRICT OF COLUMBIA PUBLIC SCHOOLS   1382282   146366        0
# 1   46155.0  DISTRICT OF COLUMBIA PUBLIC SCHOOLS   1382282   146366        0
# 2   46155.0  DISTRICT OF COLUMBIA PUBLIC SCHOOLS   1382282   146366        0
# 3   46155.0  DISTRICT OF COLUMBIA PUBLIC SCHOOLS   1382282   146366        0
# 4  182384.0                HAWAII PUBLIC SCHOOLS   2703683   259390  2381547
#
#               ...              TCAPOUT  TOTAL_REVENUE  FEDERAL_REVENUE  \
# 0             ...               381902        1382282           146366
# 1             ...               381902        1382282           146366
# 2             ...               381902        1382282           146366
# 3             ...               381902        1382282           146366
# 4             ...               161801        2703683           259390
#
#    STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  INSTRUCTION_EXPENDITURE  \
# 0              0        1235916            1360942                   557345
# 1              0        1235916            1360942                   557345
# 2              0        1235916            1360942                   557345
# 3              0        1235916            1360942                   557345
# 4        2381547          62746            2521004                  1377713
#
#    SUPPORT_SERVICES_EXPENDITURE  OTHER_EXPENDITURE  CAPITAL_OUTLAY_EXPENDITURE
# 0                        379854            41841.0                      381902
# 1                        379854            41841.0                      381902
# 2                        379854            41841.0                      381902
# 3                        379854            41841.0                      381902
# 4                        835930           145560.0                      161801
#
# [5 rows x 25 columns]

# %%
# cleaning up 
education_finances_df = education_finances_df[["YEAR", 'STATE', 'NAME', 'AVG_SCORE', 'TEST_SUBJECT', 'TEST_YEAR', 'TOTAL_REVENUE', 'FEDERAL_REVENUE', 'STATE_REVENUE', 'LOCAL_REVENUE', 'TOTAL_EXPENDITURE', 'INSTRUCTION_EXPENDITURE', 'SUPPORT_SERVICES_EXPENDITURE', 'OTHER_EXPENDITURE']].copy()
#education_finances_df.head()

#education_finances_df = education_finances_df[[ "YEAR", "STATE", "NAME", "ENROLL", "AVG_SCORE", "TEST_SUBJECT", "TEST_YEAR", "TOTAL_REVENUE","INSTRUCTION_EXPENDITURE", "SUPPORT_SERVICES_EXPENDITURE", "OTHER_EXPENDITURE"]].copy()


# Get rid of "-" values because this will affect your values on SQL later on 

mask = (education_finances_df['AVG_SCORE'] == '—')
education_finances_df['AVG_SCORE'][mask] = 0

#education_finances_df['OTHER_EXPENDITURE'].unique()

education_finances_df = education_finances_df.fillna(0)


education_finances_df.head(500)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
#      YEAR                 STATE                                 NAME  \
# 0    2015  District of Columbia  DISTRICT OF COLUMBIA PUBLIC SCHOOLS
# 1    2015  District of Columbia  DISTRICT OF COLUMBIA PUBLIC SCHOOLS
# 2    2015  District of Columbia  DISTRICT OF COLUMBIA PUBLIC SCHOOLS
# 3    2015  District of Columbia  DISTRICT OF COLUMBIA PUBLIC SCHOOLS
# 4    2015                Hawaii                HAWAII PUBLIC SCHOOLS
# 5    2015                Hawaii                HAWAII PUBLIC SCHOOLS
# 6    2015                Hawaii                HAWAII PUBLIC SCHOOLS
# 7    2015                Hawaii                HAWAII PUBLIC SCHOOLS
# 8    2013  District of Columbia  DISTRICT OF COLUMBIA PUBLIC SCHOOLS
# 9    2013  District of Columbia  DISTRICT OF COLUMBIA PUBLIC SCHOOLS
# 10   2013  District of Columbia  DISTRICT OF COLUMBIA PUBLIC SCHOOLS
# 11   2013  District of Columbia  DISTRICT OF COLUMBIA PUBLIC SCHOOLS
# 12   2013                Hawaii                HAWAII PUBLIC SCHOOLS
# 13   2013                Hawaii                HAWAII PUBLIC SCHOOLS
# 14   2013                Hawaii                HAWAII PUBLIC SCHOOLS
# 15   2013                Hawaii                HAWAII PUBLIC SCHOOLS
# 16   2011  District of Columbia  DISTRICT OF COLUMBIA PUBLIC SCHOOLS
# 17   2011  District of Columbia  DISTRICT OF COLUMBIA PUBLIC SCHOOLS
# 18   2011  District of Columbia  DISTRICT OF COLUMBIA PUBLIC SCHOOLS
# 19   2011  District of Columbia  DISTRICT OF COLUMBIA PUBLIC SCHOOLS
# 20   2011                Hawaii                HAWAII PUBLIC SCHOOLS
# 21   2011                Hawaii                HAWAII PUBLIC SCHOOLS
# 22   2011                Hawaii                HAWAII PUBLIC SCHOOLS
# 23   2011                Hawaii                HAWAII PUBLIC SCHOOLS
# 24   2009  District of Columbia                    DC PUBLIC SCHOOLS
# 25   2009  District of Columbia                    DC PUBLIC SCHOOLS
# 26   2009  District of Columbia                    DC PUBLIC SCHOOLS
# 27   2009  District of Columbia                    DC PUBLIC SCHOOLS
# 28   2009                Hawaii                HAWAII PUBLIC SCHOOLS
# 29   2009                Hawaii                HAWAII PUBLIC SCHOOLS
# ..    ...                   ...                                  ...
# 470  1992                Alaska                   YUKON-KOYUKUK REAA
# 471  1992                Alaska            BRISTOL BAY BORO SCH DIST
# 472  1992                Alaska                FAIRBANKS N STAR BORO
# 473  1992                Alaska              HAINES BOROUGH SCH DIST
# 474  1992                Alaska                 KENAI PENINSULA BORO
# 475  1992                Alaska               KETCHIKAN-GATEWAY BORO
# 476  1992                Alaska         NORTHWEST ARTIC BORO SCHOOLS
# 477  1992                Alaska                   KODIAK ISLAND BORO
# 478  1992                Alaska                    MATANUSKA SUSITNA
# 479  1992                Alaska          NORTH SLOPE BOROUGH SCHOOLS
# 480  1992                Alaska      ALEUTIANS EAST BORO SCHOOL DIST
# 481  1992                Alaska      LAKE AND PENINSULA BORO SCHOOLS
# 482  1992                Alaska               UNALASKA CITY SCH DIST
# 483  1992                Alaska                   ANCHORAGE SCH DIST
# 484  1992                Alaska             DILLINGHAM CITY SCH DIST
# 485  1992                Alaska      JUNEAU BOROUGH SCHOOLS DISTRICT
# 486  1992                Alaska                   NOME CITY SCH DIST
# 487  1992                Alaska                  CRAIG CITY SCH DIST
# 488  1992                Alaska               HYDABURG CITY SCH DIST
# 489  1992                Alaska             KLAWOCK CITY SCHOOL DIST
# 490  1992                Alaska                SITKA BOROUGH SCHOOLS
# 17                         389526            56132.0
# 18                         389526            56132.0
# 19                         389526            56132.0
# 20                         786284           133810.0
# 21                         786284           133810.0
# 22                         786284           133810.0
# 23                         786284           133810.0
# 24                         370127            38514.0
# 25                         370127            38514.0
# 26                         370127            38514.0
# 27                         370127            38514.0
# 28                         718309           129473.0
# 29                         718309           129473.0
# ..                            ...                ...
# 470                        350902                0.0
# 471                        350902                0.0
# 472                        350902                0.0
# 473                        350902                0.0
# 474                        350902                0.0
# 475                        350902                0.0
# 476                        350902                0.0
# 477                        350902                0.0
# 478                        350902                0.0
# 479                        350902                0.0
# 480                        350902                0.0
# 481                        350902                0.0
# 482                        350902                0.0
# 483                        350902                0.0
# 484                        350902                0.0
# 485                        350902                0.0
# 486                        350902                0.0
# 487                        350902                0.0
# 488                        350902                0.0
# 489                        350902                0.0
# 490                        350902                0.0
# 491                        350902                0.0
# 492                        350902                0.0
# 493                        350902                0.0
# 494                        350902                0.0
# 495                        350902                0.0
# 496                        350902                0.0
# 497                        350902                0.0
# 498                        350902                0.0
# 499                        350902                0.0
#
# [500 rows x 14 columns]

# %%
#csv file that can be used for SQL later 
education_finances_df.to_csv('education_sql.csv', index=False)

# %%
#renaming the columns for cleaning purposes 

education_finances_df = education_finances_df.rename(columns={'YEAR': 'Year',
                                                             'STATE': 'State',
                                                             'NAME': 'District Name',
                                                             'AVG_SCORE': 'Average Score',
                                                             'TEST_SUBJECT': 'Test Subject',
                                                             'TEST_YEAR': 'Grade Year',
                                                             'TOTAL_REVENUE': 'Total Revenue',
                                                             'FEDERAL_REVENUE': 'Federal Revenue',
                                                             'STATE_REVENUE': 'State Revenue',
                                                             'LOCAL_REVENUE': 'Local Revenue',
                                                             'TOTAL_EXPENDITURE': 'Total Expenditure',
                                                             'INSTRUCTION_EXPENDITURE': 'Instructors Expenditures',
                                                             'SUPPORT_SERVICES_EXPENDITURE': 'Support Services Expenditures',
                                                             'OTHER_EXPENDITURE': 'Other Expenditures'})

# %%
education_finances_df.head(500)
# Out:
#      Year                 State                        District Name  \
# 0    2015  District of Columbia  DISTRICT OF COLUMBIA PUBLIC SCHOOLS
# 1    2015  District of Columbia  DISTRICT OF COLUMBIA PUBLIC SCHOOLS
# 2    2015  District of Columbia  DISTRICT OF COLUMBIA PUBLIC SCHOOLS
# 3    2015  District of Columbia  DISTRICT OF COLUMBIA PUBLIC SCHOOLS
# 4    2015                Hawaii                HAWAII PUBLIC SCHOOLS
# 5    2015                Hawaii                HAWAII PUBLIC SCHOOLS
# 6    2015                Hawaii                HAWAII PUBLIC SCHOOLS
# 7    2015                Hawaii                HAWAII PUBLIC SCHOOLS
# 8    2013  District of Columbia  DISTRICT OF COLUMBIA PUBLIC SCHOOLS
# 9    2013  District of Columbia  DISTRICT OF COLUMBIA PUBLIC SCHOOLS
# 10   2013  District of Columbia  DISTRICT OF COLUMBIA PUBLIC SCHOOLS
# 11   2013  District of Columbia  DISTRICT OF COLUMBIA PUBLIC SCHOOLS
# 12   2013                Hawaii                HAWAII PUBLIC SCHOOLS
# 13   2013                Hawaii                HAWAII PUBLIC SCHOOLS
# 14   2013                Hawaii                HAWAII PUBLIC SCHOOLS
# 15   2013                Hawaii                HAWAII PUBLIC SCHOOLS
# 16   2011  District of Columbia  DISTRICT OF COLUMBIA PUBLIC SCHOOLS
# 17   2011  District of Columbia  DISTRICT OF COLUMBIA PUBLIC SCHOOLS
# 18   2011  District of Columbia  DISTRICT OF COLUMBIA PUBLIC SCHOOLS
# 19   2011  District of Columbia  DISTRICT OF COLUMBIA PUBLIC SCHOOLS
# 20   2011                Hawaii                HAWAII PUBLIC SCHOOLS
# 21   2011                Hawaii                HAWAII PUBLIC SCHOOLS
# 22   2011                Hawaii                HAWAII PUBLIC SCHOOLS
# 23   2011                Hawaii                HAWAII PUBLIC SCHOOLS
# 24   2009  District of Columbia                    DC PUBLIC SCHOOLS
# 25   2009  District of Columbia                    DC PUBLIC SCHOOLS
# 26   2009  District of Columbia                    DC PUBLIC SCHOOLS
# 27   2009  District of Columbia                    DC PUBLIC SCHOOLS
# 28   2009                Hawaii                HAWAII PUBLIC SCHOOLS
# 29   2009                Hawaii                HAWAII PUBLIC SCHOOLS
# ..    ...                   ...                                  ...
# 470  1992                Alaska                   YUKON-KOYUKUK REAA
# 471  1992                Alaska            BRISTOL BAY BORO SCH DIST
# 472  1992                Alaska                FAIRBANKS N STAR BORO
# 473  1992                Alaska              HAINES BOROUGH SCH DIST
# 496           106780         720711         222100             972488
# 497           106780         720711         222100             972488
# 498           106780         720711         222100             972488
# 499           106780         720711         222100             972488
#
#      Instructors Expenditures  Support Services Expenditures  \
# 0                      557345                         379854
# 1                      557345                         379854
# 2                      557345                         379854
# 3                      557345                         379854
# 4                     1377713                         835930
# 5                     1377713                         835930
# 6                     1377713                         835930
# 7                     1377713                         835930
# 8                      559940                         332997
# 9                      559940                         332997
# 10                     559940                         332997
# 11                     559940                         332997
# 12                    1283872                         770643
# 13                    1283872                         770643
# 14                    1283872                         770643
# 15                    1283872                         770643
# 16                     525185                         389526
# 17                     525185                         389526
# 18                     525185                         389526
# 19                     525185                         389526
# 20                    1253534                         786284
# 21                    1253534                         786284
# 22                    1253534                         786284
# 23                    1253534                         786284
# 24                     330698                         370127
# 25                     330698                         370127
# 26                     330698                         370127
# 27                     330698                         370127
# 28                    1402305                         718309
# 29                    1402305                         718309
# ..                        ...                            ...
# 470                    498362                         350902
# 471                    498362                         350902
# 472                    498362                         350902
# 473                    498362                         350902
# 474                    498362                         350902
# 475                    498362                         350902
# 476                    498362                         350902
# 477                    498362                         350902
# 478                    498362                         350902
# 479                    498362                         350902
# 480                    498362                         350902
# 481                    498362                         350902
# 482                    498362                         350902
# 483                    498362                         350902
# 484                    498362                         350902
# 485                    498362                         350902
# 486                    498362                         350902
# 487                    498362                         350902
# 488                    498362                         350902
# 489                    498362                         350902
# 490                    498362                         350902
# 491                    498362                         350902
# 492                    498362                         350902
# 493                    498362                         350902
# 494                    498362                         350902
# 495                    498362                         350902
# 496                    498362                         350902
# 497                    498362                         350902
# 498                    498362                         350902
# 499                    498362                         350902
#
#      Other Expenditures
# 0               41841.0
# 1               41841.0
# 2               41841.0
# 3               41841.0
# 4              145560.0
# 5              145560.0
# 6              145560.0
# 7              145560.0
# 8               39825.0
# 9               39825.0
# 10              39825.0
# 11              39825.0
# 12             144746.0
# 13             144746.0
# 14             144746.0
# 15             144746.0
# 16              56132.0
# 17              56132.0
# 18              56132.0
# 19              56132.0
# 20             133810.0
# 21             133810.0
# 22             133810.0
# 23             133810.0
# 24              38514.0
# 25              38514.0
# 26              38514.0
# 27              38514.0
# 28             129473.0
# 29             129473.0
# ..                  ...
# 470                 0.0
# 471                 0.0
# 472                 0.0
# 473                 0.0
# 474                 0.0
# 475                 0.0
# 476                 0.0
# 477                 0.0
# 478                 0.0
# 479                 0.0
# 480                 0.0
# 481                 0.0
# 482                 0.0
# 483                 0.0
# 484                 0.0
# 485                 0.0
# 486                 0.0
# 487                 0.0
# 488                 0.0
# 489                 0.0
# 490                 0.0
# 491                 0.0
# 492                 0.0
# 493                 0.0
# 494                 0.0
# 495                 0.0
# 496                 0.0
# 497                 0.0
# 498                 0.0
# 499                 0.0
#
# [500 rows x 14 columns]

# %%
education_finances_df.describe()
# Out:
#                Year    Grade Year  Total Revenue  Instructors Expenditures  \
# count  47678.000000  47678.000000   4.767800e+04              4.767800e+04
# mean    1992.022400      5.334284   7.795256e+06              4.203842e+06
# std        0.613214      1.885974   7.374191e+06              4.100572e+06
# min     1992.000000      4.000000   5.516680e+05              2.834840e+05
# 25%     1992.000000      4.000000   2.396705e+06              1.283577e+06
# 50%     1992.000000      4.000000   4.993909e+06              2.598925e+06
# 75%     1992.000000      8.000000   1.081469e+07              6.042936e+06
# max     2015.000000      8.000000   2.626002e+07              1.435892e+07
#
#        Support Services Expenditures  Other Expenditures
# count                   4.767800e+04        47678.000000
# mean                    2.358849e+06          133.168610
# std                     2.290069e+06         3854.796901
# min                     1.523400e+05            0.000000
# 25%                     7.350360e+05            0.000000
# 50%                     1.478639e+06            0.000000
# 75%                     3.321276e+06            0.000000
# max                     8.520926e+06       151243.000000

# %%
#extra cleaning if needed
#mask = (education_finances_df['Average Score'] == '—')
#education_finances_df['Average Score'][mask] = 0
# Out:
# Series([], Name: Average Score, dtype: object)

# %%
# try to create a graph

# %%
#download as a csv file for Tableau 
education_finances_df.to_csv('education.csv', index=False)

# %%
DROP TABLE education

CREATE TABLE education (
	"Year" INT NOT NULL,
	"State" VARCHAR(50) NOT NULL,
	"District Name" VARCHAR(50) NOT NULL, 
	"Average Score" FLOAT NOT NULL,
	"Test Subject" VARCHAR(225) NOT NULL,
	"Grade Year" INT NOT NULL,
	"Total Revenue" FLOAT NOT NULL,
	"Instructors Expenditures" FLOAT NOT NULL,
	"Support Services Expenditures" FLOAT NOT NULL,
	"Other Expenditures" FLOAT
);


SELECT * FROM education

# %%
education_finances_df.dtypes
# Out:
# Year                               int64
# State                             object
# District Name                     object
# Average Score                     object
# Test Subject                      object
# Grade Year                         int64
# Total Revenue                      int64
# Instructors Expenditures           int64
# Support Services Expenditures      int64
# Other Expenditures               float64
# dtype: object

# %%
naep_pd[['AVG_SCORE', 'STATE']].min()
# Out:
# AVG_SCORE    178.557611651728
# STATE                 Alabama
# dtype: object

# %%
Select 
"State",
"Test Subject",
"Total Revenue",
MAX("Average Score") as "Max Avg Score",
Min("Average Score") as "Min Avg Score"
from education 
Group by "Total Revenue","State", "Test Subject"
Order by "Total Revenue" DESC;

# %%
--Adding new a table 
DROP TABLE education_sql

CREATE TABLE education_sql (
	"YEAR" INT NOT NULL,
	"STATE" VARCHAR(250) NOT NULL,
	"NAME" VARCHAR(250) NOT NULL, 
	"AVG_SCORE" FLOAT NOT NULL,
	"TEST_SUBJECT" VARCHAR(225) NOT NULL, 
	"TEST_YEAR" INT NOT NULL, 
	"TOTAL_REVENUE" FLOAT NOT NULL,
	"FEDERAL_REVENUE" FLOAT,
	"STATE REVENUE" FLOAT,
	"LOCAL REVENUE" FLOAT,
	"TOTAL EXPENDITURES" FLOAT NOT NULL, 
	"INSTRUCTION_EXPENDITURE" FLOAT,
	"SUPPORT_SERVICES_EXPENDITURE" FLOAT,
	"OTHER_EXPENDITURE" FLOAT);

# %%
After looking at the data, there is no correlation between high funding within states and high test scores. 
California came out as the top highest state funding. Yet, it ranked 31 within the test scores. While Iowa scored 
highest in test scores and not even as high for funding.
